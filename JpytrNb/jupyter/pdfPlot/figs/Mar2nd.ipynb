# %%
from IPython.display import display, Image

# %%
path = './figs/BHmass_vs_SFR_InBins_ColorLine.png'
img = Image(path)
display(img)
path = './figs/BHmass_vs_sSFR_InBins_ColorLine.png'
img = Image(path)
display(img)

# %% [markdown]
# BH Mass vs. SFR(sSFR)
# --------------------

# %%
path = './figs/BHdot_vs_SFR_InBins_ColorLine.png'
img = Image(path)
display(img)
path = './figs/BHdot_vs_sSFR_InBins_ColorLine.png'
img = Image(path)
display(img)

# %% [markdown]
# BHdot vs. SFR(sSFR)
# --------------------

# %%
path = './figs/BHdot_GF_colorline.png'
img = Image(path)
display(img)
path = './figs/BHMass_GF_colorline.png'
img = Image(path)
display(img)
path = './figs/SFR_GF_colorline.png'
img = Image(path)
display(img)

# %% [markdown]
# BHdot, BHmass, SFR vs. GF
# --------------------

# %%
path = './figs/BHdot_rs3GF_colorline.png'
img = Image(path)
display(img)
path = './figs/BHmass_rs3GF_colorline.png'
img = Image(path)
display(img)
path = './figs/SFR_rs3GF_colorline.png'
img = Image(path)
display(img)

# %% [markdown]
# BHdot, BHmass, SFR vs. f_gas(z)/f_gas(z=3.0)
# --------------------
