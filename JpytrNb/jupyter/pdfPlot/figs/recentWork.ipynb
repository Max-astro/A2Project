# %%
from IPython.display import display, Image

# %%
path = './figs/A2_Redshift.png'
img = Image(path)
display(img)

# %% [markdown]
# Fig: The relation between zbar & a2
# -----------------
# 这张图是为了更好的描述我们定义的zbar而画的，红线是该星系的zbar，黄线是Zformation

# %%
path = './figs/fp_figs.png'
img = Image(path)
display(img)

# %% [markdown]
# Fig: False positive halo samples
# --------------
# 这4张图是为了展示false positive的样本，左列是tng的样本，右列是illustris-1的样本。这些样本代表了大多数a2大于0.15但是却没有通过视觉上检验的halo的特点：高a2是由于bar以外的子结构所引起的。

# %%
path='./figs/MgasDivSFR.png'
img = Image(path)
display(img)

# %% [markdown]
# Fig: The relation between Mgas / SFR and z
# --------------
# 这是之前你让我画的，我不太清楚用途。

# %% [markdown]
# 后面的图也是您之前说想看看多个量之间关系的图。其中有箭头的点是一条线的起始点。
# ------
# 全部放上来不再另外给注释了。

# %%
path='./figs/BH_dot&M_vs_SFR_InBins.png'
img = Image(path)
display(img)

# %%
path='./figs/BH_dot&M_vs_SFR.png'
img = Image(path)
display(img)

# %%
path='./figs/BH_dot&M_vs_sSFR_InBins.png'
img = Image(path)
display(img)

# %%
path='./figs/BH_dot&M_vs_sSFR.png'
img = Image(path)
display(img)

# %%
path='./figs/BHdot&M_vs_Mgas&SFR_InBins.png'
img = Image(path)
display(img)

# %%
path='./figs/BHdot&M_vs_Mgas&SFR.png'
img = Image(path)
display(img)
